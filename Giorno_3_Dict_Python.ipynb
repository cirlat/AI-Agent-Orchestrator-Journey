# %% [markdown]
# <a href="https://colab.research.google.com/github/cirlat/AI-Agent-Orchestrator-Journey/blob/main/Giorno_3_Dict_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Definiamo un dizionario (Pensa a una riga di database con nomi di colonna)
utente_ai = {
    "id": "001",
    "cognome": "ROSSI",
    "nome": "MARIO",
    "ruolo": "Analista Programmatore",
    "competenze": ["COBOL", "Windows Server", "SQL"],
    "stato_certificazione": False
}

# 2. Accedere ai dati (Molto più leggibile della logica posizionale!)
print(f"Sto analizzando il profilo di: {utente_ai['cognome']}")

# 3. Modifica dinamica: Aggiungiamo una nuova competenza "IA"
utente_ai["competenze"].append("Python per AI")

# 4a. Visualizzo il profilo attuale
print(utente_ai)

# 4b. modifico lo stato della certificazione
utente_ai["stato_certificazione"]=True

# 5. Simuliamo un "Prompt" per l'IA usando i dati del dizionario
prompt_per_ia = f"Genera un piano di carriera per {utente_ai['nome']} {utente_ai['cognome']}, esperto in {utente_ai['competenze']}. Stato certificazione: {utente_ai['stato_certificazione']}"

print("-" * 30)
print("PROMPT GENERATO PER L'AGENTE:")
print(prompt_per_ia)
# Out:
# Sto analizzando il profilo di: ROSSI
# {'id': '001', 'cognome': 'ROSSI', 'nome': 'MARIO', 'ruolo': 'Analista Programmatore', 'competenze': ['COBOL', 'Windows Server', 'SQL', 'Python per AI'], 'stato_certificazione': False}
# ------------------------------
# PROMPT GENERATO PER L'AGENTE:
# Genera un piano di carriera per MARIO ROSSI, esperto in ['COBOL', 'Windows Server', 'SQL', 'Python per AI']. Stato certificazione: True
