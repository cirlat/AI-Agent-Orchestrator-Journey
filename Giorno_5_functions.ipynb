# %% [markdown]
# <a href="https://colab.research.google.com/github/cirlat/AI-Agent-Orchestrator-Journey/blob/main/Giorno_5_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definizione della funzione (Il tuo nuovo "Sottoprogramma")
def prepara_messaggio_per_ia(errore_testo, gravita="ALTA"):
    # Logica interna: formattazione professionale
    messaggio = f"### ALERT SISTEMA ###\nGravità: {gravita}\nDescrizione: {errore_testo}\nRichiesta: Suggerisci una soluzione tecnica."
    return messaggio

def calcola_sconto(prezzo, sconto="20"):
  prezzo_scontato=prezzo - (prezzo * (20 / 100))
  print(f"il prezzo scontato è {prezzo_scontato}")
  return prezzo_scontato

# --- MAIN PROGRAM ---
errore_rilevato = "Timeout connessione SQL Server su Windows 2022"

# Chiamata alla funzione
prompt_finale = prepara_messaggio_per_ia(errore_rilevato)
scont = calcola_sconto(36)

print(prompt_finale)

# SFIDA: Crea una funzione chiamata 'calcola_sconto' che riceve un 'prezzo'
# e restituisce il prezzo scontato del 20%.
# Out:
# il prezzo scontato è 28.8
# ### ALERT SISTEMA ###
# Gravità: ALTA
# Descrizione: Timeout connessione SQL Server su Windows 2022
# Richiesta: Suggerisci una soluzione tecnica.
